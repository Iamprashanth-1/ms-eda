# %%
import pandas as pd

# %%
df=pd.read_csv('Datas1.csv')

# %%
df.head()
# Out:
#     SKU  01-08-2019  02-08-2019  03-08-2019  04-08-2019  05-08-2019  \
# 0  2527        1551        1613        1613        1532        1517
# 1  3042        2240        2330        2423        2350        2374
# 2  3086         891         909         936         889         880
# 3  3155        1628        1628        1563        1532        1563
# 4  3166         369         354         343         340         330
#
#    06-08-2019  07-08-2019  08-08-2019  09-08-2019  ...  22-07-2020  \
# 0        1441        1383        1424        1381  ...        1929
# 1        2398        2278        2210        2232  ...        7096
# 2         906         870         879         844  ...         829
# 3        1563        1532        1593        1513  ...        1719
# 4         337         350         343         340  ...         335
#
#    23-07-2020  24-07-2020  25-07-2020  26-07-2020  27-07-2020  28-07-2020  \
# 0        1948        1929        1987        2027        1926        1926
# ...

# %%
sd=df.sum(axis = 0, skipna = True)
sd=sd[1:]

# %%
dat=[]
valu=[]
for i,v in sd.items():
    dat.append(i)
    valu.append(v)

# %%
import plotly.graph_objects as go
from collections import Counter
import datetime
import pandas as pd
import plotly.express as px
import dash_bootstrap_components as dbc
import dash
import dash_core_components as dcc
import dash_html_components as html

dif=dict()
sif=[]
dif['Date']=dat
dif['count']=valu
sif.append(dif)
fig7 =px.line(dif,x='Date',y='count',title='Time Series with Range Slider and Selectors')

fig7.update_xaxes(
    rangeslider_visible=True,
    rangeselector=dict(
        buttons=list([
            dict(count=1, label="1m", step="month", stepmode="backward"),
            dict(count=6, label="6m", step="month", stepmode="backward"),
            dict(count=1, label="YTD", step="year", stepmode="todate"),
            dict(count=1, label="1y", step="year", stepmode="backward"),
            dict(step="all")
        ])
    )
)


fig7.update_layout(
    height=600,
    template="plotly_dark",

)
fig7.update_xaxes(rangeslider_visible=True)

# %%
ds=list(df)
ds=ds[1:]
print(ds[-1])
# Out:
# 07-2020

# %%
cv=[]
csx=[]
for i in range(len(ds)-1):
    p=ds[i][3:5]
    if p==ds[i+1][3:5]:
        cv.append(ds[i])
    else:
        cv.append(ds[i])
        #print(cv)
        csx.append(cv)
        cv=[]
csx.append(cv)

# %%
print(csx)
# Out:
# [['01-08-2019', '02-08-2019', '03-08-2019', '04-08-2019', '05-08-2019', '06-08-2019', '07-08-2019', '08-08-2019', '09-08-2019', '10-08-2019', '11-08-2019', '12-08-2019', '13-08-2019', '14-08-2019', '15-08-2019', '16-08-2019', '17-08-2019', '18-08-2019', '19-08-2019', '20-08-2019', '21-08-2019', '22-08-2019', '23-08-2019', '24-08-2019', '25-08-2019', '26-08-2019', '27-08-2019', '28-08-2019', '29-08-2019', '30-08-2019', '31-08-2019'], ['01-09-2019', '02-09-2019', '03-09-2019', '04-09-2019', '05-09-2019', '06-09-2019', '07-09-2019', '08-09-2019', '09-09-2019', '10-09-2019', '11-09-2019', '12-09-2019', '13-09-2019', '14-09-2019', '15-09-2019', '16-09-2019', '17-09-2019', '18-09-2019', '19-09-2019', '20-09-2019', '21-09-2019', '22-09-2019', '23-09-2019', '24-09-2019', '25-09-2019', '26-09-2019', '27-09-2019', '28-09-2019', '29-09-2019', '30-09-2019'], ['01-10-2019', '02-10-2019', '03-10-2019', '04-10-2019', '05-10-2019', '06-10-2019', '07-10-2019', '08-10-2019', '09-10-2019', '10-10-2019'
# ...

# %%
fgs=[]
for i in csx:
    gv=str(i[0][3:])
    fgs.append(gv)
    df[gv]=df[i].sum(axis=1)

# %%
df.sort_values(by =fgs,ascending=True)
# Out:
#        SKU  01-08-2019  02-08-2019  03-08-2019  04-08-2019  05-08-2019  \
# 132  98201           1           1           1           1           1
# 136  98220           1           1           1           1           1
# 137  98222           1           1           1           1           1
# 103  98013           2           2           2           2           2
# 118  98047           2           2           2           2           2
# ..     ...         ...         ...         ...         ...         ...
# 51   38320       22585       23037       23037       22346       23463
# 47   38194       23441       23441       24379       24867       24867
# 78   65202       25317       26077       25034       25535       25535
# 14   14119       36207       34759       36149       35426       34009
# 74   65001       83599       79419       82596       83422       82588
#
#      06-08-2019  07-08-2019  08-08-2019  09-08-2019  ...  11-2019  12-2019  \
# ...

# %%
sda=df.sum(axis = 0, skipna = True)
sda=sda[367:]

print('montly sales')
sda
# Out:
# montly sales
# 08-2019     16590204
# 09-2019     17309331
# 10-2019     18300108
# 11-2019     17954015
# 12-2019     19536270
# 01-2020     19170099
# 02-2020     17973457
# 03-2020     20234570
# 04-2020     19103472
# 05-2020     18555947
# 06-2020     18303531
# 07-2020     18795771
# 2019       203031004
# dtype: object
